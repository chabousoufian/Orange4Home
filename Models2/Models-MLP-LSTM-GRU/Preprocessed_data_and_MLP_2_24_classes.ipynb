# %%
import pandas as pd
import numpy as np
import re

from google.colab import drive
drive.mount('/content/drive')

import os
# Out:
# Mounted at /content/drive

# %%
all_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Mini-Projet/sensor_data_processed_normalizing_the_label_with_hot_encoding_24_classes.csv')

# %%
X = all_data[['bedroom_switch_middle_left',
 'entrance_heater_effective_setpoint',
 'bedroom_switch_middle_right',
 'kitchen_noise',
 'livingroom_couch_plug_consumption',
 'global_snow_ext',
 'bedroom_heater1_effective_setpoint',
 'global_lighting_power',
 'livingroom_heater2_base_setpoint',
 'kitchen_dishwasher_current',
 'toilet_coldwater_total',
 'kitchen_hood_voltage',
 'kitchen_washingmachine_partial_energy',
 'walkway_switch2_bottom_left',
 'livingroom_shutter5',
 'kitchen_hood_total_energy',
 'bathroom_heater_command',
 'walkway_noise',
 'entrance_noise',
 'livingroom_shutter4',
 'livingroom_switch2_top_left',
 'global_rain_ext',
 'global_wind_speed_ext',
 'global_waterheater_total_energy',
 'global_lighting_current',
 'livingroom_heater2_temperature',
 'livingroom_tv_status',
 'office_tv_plug_consumption',
 'kitchen_fridge_power',
 'bedroom_closet_door',
 'bathroom_luminosity',
 'livingroom_tv_plug_consumption',
 'office_AC_setpoint',
 'bathroom_switch_bottom_right',
 'bedroom_light4',
 'office_heater_effective_mode',
 'global_lighting_total_energy',
 'kitchen_cupboard3',
 'toilet_switch_left',
 'entrance_heater_base_setpoint',
 'office_heater_command',
 'bedroom_light2',
 'livingroom_table_luminosity',
 'global_voltage',
 'bedroom_temperature',
 'kitchen_fridge_door',
 'bathroom_sink_coldwater_total',
 'global_lighting_partial_energy',
 'livingroom_couch_noise',
 'global_temperature_feel_ext',
 'livingroom_humidity',
 'kitchen_oven_current',
 'livingroom_presence_table',
 'bathroom_switch_bottom_left',
 'livingroom_heater1_command',
 'staircase_light',
 'office_noise',
 'kitchen_sink_hotwater_total',
 'bathroom_switch_top_right',
 'bedroom_switch_bottom_left',
 'livingroom_presence_couch',
 'livingroom_heater2_effective_setpoint',
 'bedroom_presence',
 'toilet_switch_right',
 'bedroom_humidity',
 'livingroom_heater1_effective_mode',
 'bedroom_heater2_effective_setpoint',
 'livingroom_heater2_command',
 'bedroom_shutter1',
 'global_active_power',
 'walkway_switch1_bottom_left',
 'kitchen_hood_current',
 'entrance_heater_temperature',
 'bedroom_CO2',
 'livingroom_table_plug_consumption',
 'bathroom_CO2',
 'bathroom_temperature',
 'bedroom_drawer1',
 'office_switch_right',
 'global_heaters_temperature',
 'global_waterheater_current',
 'kitchen_dishwasher_voltage',
 'global_shutters_voltage',
 'walkway_switch1_bottom_right',
 'livingroom_heater1_effective_setpoint',
 'livingroom_light1',
 'bathroom_heater_temperature',
 'kitchen_cooktop_current',
 'entrance_switch_left',
 'toilet_coldwater_instantaneous',
 'kitchen_oven_voltage',
 'bathroom_sink_hotwater_instantaneous',
 'staircase_switch_right',
 'kitchen_sink_coldwater_instantaneous',
 'livingroom_heater2_effective_mode',
 'office_tv_status',
 'global_shutters_current',
 'kitchen_fridge_current',
 'kitchen_washingmachine_total_energy',
 'bedroom_shutter2',
 'bathroom_light2',
 'global_waterheater_partial_energy',
 'global_frequency',
 'kitchen_switch_bottom_right',
 'bedroom_door',
 'kitchen_luminosity',
 'bedroom_heater2_command',
 'entrance_heater_command',
 'global_pressure_ext',
 'kitchen_oven_partial_energy',
 'global_shutters_power',
 'office_luminosity',
 'kitchen_cooktop_total_energy',
 'kitchen_washingmachine_voltage',
 'bathroom_light1',
 'bedroom_luminosity',
 'office_presence',
 'bathroom_heater_effective_setpoint',
 'bathroom_shower_hotwater_instantaneous',
 'livingroom_switch1_top_left',
 'bathroom_humidity',
 'kitchen_cupboard5',
 'bathroom_shower_coldwater_total',
 'bathroom_shower_coldwater_instantaneous',
 'office_window',
 'kitchen_switch_bottom_left',
 'kitchen_dishwasher_partial_energy',
 'kitchen_fridge_voltage',
 'office_heater_effective_setpoint',
 'office_heater_temperature',
 'livingroom_window1',
 'bathroom_sink_hotwater_total',
 'kitchen_cooktop_voltage',
 'kitchen_hood_power',
 'kitchen_sink_hotwater_instantaneous',
 'global_current',
 'global_condition_id_ext',
 'livingroom_switch1_top_right',
 'office_AC_mode',
 'bedroom_heater2_effective_mode',
 'walkway_light',
 'bathroom_door',
 'global_clouds_ext',
 'global_shutters_total_energy',
 'bedroom_heater1_effective_mode',
 'bedroom_light1',
 'kitchen_cupboard1',
 'livingroom_temperature',
 'livingroom_CO2',
 'global_shutters_partial_energy',
 'bathroom_shower_hotwater_total',
 'kitchen_switch_top_right',
 'kitchen_cooktop_partial_energy',
 'global_waterheater_power',
 'kitchen_sink_coldwater_total',
 'kitchen_oven_total_energy',
 'global_power_factor',
 'kitchen_washingmachine_current',
 'global_coldwater_instantaneous',
 'office_desk_plug_consumption',
 'livingroom_switch1_bottom_left',
 'entrance_door',
 'global_active_energy',
 'global_coldwater_total',
 'bathroom_heater_effective_mode',
 'office_light',
 'walkway_switch1_top_right',
 'global_humidity_ext',
 'livingroom_AC_setpoint',
 'walkway_switch2_top_right',
 'bathroom_switch_top_left',
 'kitchen_cupboard2',
 'office_heater_base_setpoint',
 'bedroom_light3',
 'kitchen_dishwasher_total_energy',
 'livingroom_shutter3',
 'kitchen_light2',
 'kitchen_cooktop_power',
 'office_switch_left',
 'toilet_light',
 'livingroom_shutter2',
 'bathroom_presence',
 'livingroom_light2',
 'bedroom_switch_top_right',
 'livingroom_heater1_temperature',
 'bedroom_switch_top_left',
 'walkway_switch1_top_left',
 'livingroom_switch2_top_right',
 'walkway_switch2_bottom_right',
 'kitchen_dishwasher_power',
 'global_heaters_setpoint',
 'bedroom_AC_setpoint',
 'kitchen_temperature',
 'bedroom_heater2_temperature',
 'kitchen_fridge_partial_energy',
 'bedroom_switch_bottom_right',
 'office_shutter',
 'bedroom_drawer2',
 'global_temperature_ext',
 'bedroom_heater1_command',
 'bathroom_heater_base_setpoint',
 'bedroom_bed_pressure',
 'livingroom_table_noise',
 'global_lighting_voltage',
 'office_switch_middle',
 'global_gas_total',
 'global_waterheater_status',
 'office_door',
 'kitchen_washingmachine_power',
 'staircase_switch_left',
 'bedroom_heater2_base_setpoint',
 'entrance_heater_effective_mode',
 'bedroom_heater1_temperature',
 'entrance_light1',
 'livingroom_shutter1',
 'livingroom_heater1_base_setpoint',
 'kitchen_CO2',
 'walkway_switch2_top_left',
 'kitchen_switch_top_left',
 'kitchen_fridge_total_energy',
 'bathroom_shower_door',
 'bedroom_heater1_base_setpoint',
 'kitchen_light1',
 'kitchen_hood_partial_energy',
 'global_waterheater_voltage',
 'kitchen_cupboard4',
 'bathroom_sink_coldwater_instantaneous',
 'bedroom_noise',
 'kitchen_humidity',
 'kitchen_oven_power',
 'kitchen_presence',
 'livingroom_luminosity',
 'E',
 'ENE',
 'ESE',
 'N',
 'NE',
 'NNE',
 'NNW',
 'NW',
 'S',
 'SE',
 'SSE',
 'SSW',
 'SW',
 'W',
 'WNW',
 'WSW',
 'down',
 'equal',
 'up',
 'Couvert',
 'brouillard',
 'brume',
 'ensoleillé',
 'légères pluies',
 'nuageux',
 'partiellement ensoleillé',
 'peu nuageux',
 'cloudy',
 'few-showers',
 'fog',
 'mostly-cloudy-day',
 'partly-cloudy-day',
 'sunny']]

# %%
y = all_data[['Bathroom|Cleaning',
 'Bathroom|Showering',
 'Bathroom|Using_the_sink',
 'Bathroom|Using_the_toilet',
 'Bedroom|Cleaning',
 'Bedroom|Dressing',
 'Bedroom|Napping',
 'Bedroom|Reading',
 'Entrance|Entering',
 'Entrance|Leaving',
 'Kitchen|Cleaning',
 'Kitchen|Cooking',
 'Kitchen|Preparing',
 'Kitchen|Washing_the_dishes',
 'Living_room|Cleaning',
 'Living_room|Computing',
 'Living_room|Eating',
 'Living_room|Watching_TV',
 'Office|Cleaning',
 'Office|Computing',
 'Office|Watching_TV',
 'Staircase|Going_down',
 'Staircase|Going_up',
 'Toilet|Using_the_toilet']]

# %%
y = y.values

# %%
X = X.values

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)
x_test, x_val, y_test, y_val = train_test_split(x_test,y_test, test_size = 0.3)

# %% [markdown]
# #MLP Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, SGD
# Plot
import matplotlib.pyplot as plt

# %%
# hyper-parameters
num_classes = 24


model = Sequential()
# first layer with 
model.add(Dense(x_train.shape[1], activation='relu', input_shape=(x_train.shape[1],)))
# second layer with 
model.add(Dense((x_train.shape[1]+num_classes)/2, activation='relu'))
# Dropout of 50%
model.add(Dropout(0.5))
# Camada de 20 neurônios
model.add(Dense((x_train.shape[1]+num_classes)/2, activation='relu'))

# Classification Layer 
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 265)               70490
#
#  dense_1 (Dense)             (None, 144)               38304
#
#  dropout (Dropout)           (None, 144)               0
#
#  dense_2 (Dense)             (None, 144)               20880
#
#  dense_3 (Dense)             (None, 24)                3480
#
# =================================================================
# Total params: 133,154
# Trainable params: 133,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %%
# %%time
batch_size = 34
epochs = 30
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 7786/7786 [==============================] - 43s 5ms/step - loss: 1.0928 - accuracy: 0.7266 - val_loss: 0.6467 - val_accuracy: 0.8539
# Epoch 2/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.5747 - accuracy: 0.8494 - val_loss: 0.3999 - val_accuracy: 0.9029
# Epoch 3/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.4153 - accuracy: 0.8861 - val_loss: 0.3168 - val_accuracy: 0.9104
# Epoch 4/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.3457 - accuracy: 0.8996 - val_loss: 0.2759 - val_accuracy: 0.9175
# Epoch 5/30
# 7786/7786 [==============================] - 43s 5ms/step - loss: 0.3062 - accuracy: 0.9089 - val_loss: 0.2460 - val_accuracy: 0.9281
# Epoch 6/30
# 7786/7786 [==============================] - 45s 6ms/step - loss: 0.2760 - accuracy: 0.9178 - val_loss: 0.2209 - val_accuracy: 0.9371
# Epoch 7/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.2518 - accuracy: 0.9258 - val_loss: 0.2013 - val_accuracy: 0.9421
# Epoch 8/30
# 7786/7786 [==============================] - 43s 5ms/step - loss: 0.2310 - accuracy: 0.9329 - val_loss: 0.1844 - val_accuracy: 0.9506
# Epoch 9/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.2140 - accuracy: 0.9378 - val_loss: 0.1709 - val_accuracy: 0.9508
# Epoch 10/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1987 - accuracy: 0.9421 - val_loss: 0.1591 - val_accuracy: 0.9523
# Epoch 11/30
# 7786/7786 [==============================] - 38s 5ms/step - loss: 0.1871 - accuracy: 0.9447 - val_loss: 0.1506 - val_accuracy: 0.9550
# Epoch 12/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1775 - accuracy: 0.9473 - val_loss: 0.1421 - val_accuracy: 0.9558
# Epoch 13/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.1697 - accuracy: 0.9492 - val_loss: 0.1369 - val_accuracy: 0.9573
# Epoch 14/30
# 7786/7786 [==============================] - 39s 5ms/step - loss: 0.1615 - accuracy: 0.9510 - val_loss: 0.1304 - val_accuracy: 0.9565
# Epoch 15/30
# 7786/7786 [==============================] - 37s 5ms/step - loss: 0.1570 - accuracy: 0.9520 - val_loss: 0.1264 - val_accuracy: 0.9561
# Epoch 16/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1509 - accuracy: 0.9534 - val_loss: 0.1220 - val_accuracy: 0.9582
# Epoch 17/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1450 - accuracy: 0.9551 - val_loss: 0.1173 - val_accuracy: 0.9603
# Epoch 18/30
# 7786/7786 [==============================] - 39s 5ms/step - loss: 0.1408 - accuracy: 0.9558 - val_loss: 0.1138 - val_accuracy: 0.9604
# Epoch 19/30
# 7786/7786 [==============================] - 43s 6ms/step - loss: 0.1372 - accuracy: 0.9569 - val_loss: 0.1111 - val_accuracy: 0.9598
# Epoch 20/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1324 - accuracy: 0.9583 - val_loss: 0.1076 - val_accuracy: 0.9625
# Epoch 21/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1294 - accuracy: 0.9592 - val_loss: 0.1041 - val_accuracy: 0.9638
# Epoch 22/30
# 7786/7786 [==============================] - 38s 5ms/step - loss: 0.1254 - accuracy: 0.9600 - val_loss: 0.1021 - val_accuracy: 0.9635
# Epoch 23/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1226 - accuracy: 0.9609 - val_loss: 0.0981 - val_accuracy: 0.9651
# Epoch 24/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.1188 - accuracy: 0.9623 - val_loss: 0.0954 - val_accuracy: 0.9655
# Epoch 25/30
# 7786/7786 [==============================] - 42s 5ms/step - loss: 0.1167 - accuracy: 0.9628 - val_loss: 0.0934 - val_accuracy: 0.9662
# Epoch 26/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1141 - accuracy: 0.9636 - val_loss: 0.0913 - val_accuracy: 0.9687
# Epoch 27/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1118 - accuracy: 0.9644 - val_loss: 0.0885 - val_accuracy: 0.9693
# Epoch 28/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1089 - accuracy: 0.9653 - val_loss: 0.0863 - val_accuracy: 0.9702
# Epoch 29/30
# 7786/7786 [==============================] - 40s 5ms/step - loss: 0.1062 - accuracy: 0.9662 - val_loss: 0.0848 - val_accuracy: 0.9718
# Epoch 30/30
# 7786/7786 [==============================] - 41s 5ms/step - loss: 0.1037 - accuracy: 0.9673 - val_loss: 0.0829 - val_accuracy: 0.9719
# CPU times: user 22min 37s, sys: 55.6 s, total: 23min 33s
# Wall time: 21min 23s

# %%
from sklearn.metrics import classification_report, confusion_matrix

score = model.evaluate(x_val, y_val, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.08288705348968506
# Test accuracy: 0.971882700920105

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.08417699486017227
# Test accuracy: 0.9703460335731506

# %%
# Classification
y_pred = model.predict(x_test)

y_pred
# Out:
# 2482/2482 [==============================] - 7s 3ms/step
# array([[2.2118209e-09, 2.1139572e-14, 1.4272876e-10, ..., 1.5513383e-09,
#         3.2441507e-09, 5.0583623e-07],
#        [8.3454477e-10, 4.0080993e-15, 4.5563751e-11, ..., 5.0000803e-10,
#         1.6511212e-09, 2.6139526e-07],
#        [4.4770823e-09, 2.7175704e-13, 4.7375776e-10, ..., 6.3719492e-09,
#         1.3128719e-08, 1.9954196e-06],
#        ...,
#        [6.3269341e-05, 1.0419737e-08, 8.9340765e-06, ..., 2.5598694e-05,
#         5.7854345e-06, 2.2385368e-06],
#        [4.9977665e-08, 1.1259455e-12, 3.5427830e-09, ..., 2.8314531e-08,
#         4.2919485e-08, 5.0298986e-06],
#        [5.7059804e-08, 4.5107570e-11, 4.2268535e-09, ..., 1.4630489e-06,
#         1.6406730e-06, 5.8601419e-08]], dtype=float32)

# %%
for i in range(0,len(y_pred)):
# Get the index of the maximum value in the output list
  max_index = np.argmax(y_pred[i])
  # Create a binary vector with the maximum value as 1 and other values as 0
  y_pred[i] = np.zeros(len(y_pred[i]))

  y_pred[i][max_index] = 1

# %%
labels = ['Bathroom|Cleaning',
 'Bathroom|Showering',
 'Bathroom|Using_the_sink',
 'Bathroom|Using_the_toilet',
 'Bedroom|Cleaning',
 'Bedroom|Dressing',
 'Bedroom|Napping',
 'Bedroom|Reading',
 'Entrance|Entering',
 'Entrance|Leaving',
 'Kitchen|Cleaning',
 'Kitchen|Cooking',
 'Kitchen|Preparing',
 'Kitchen|Washing_the_dishes',
 'Living_room|Cleaning',
 'Living_room|Computing',
 'Living_room|Eating',
 'Living_room|Watching_TV',
 'Office|Cleaning',
 'Office|Computing',
 'Office|Watching_TV',
 'Staircase|Going_down',
 'Staircase|Going_up',
 'Toilet|Using_the_toilet']

# %%
df_pred = pd.DataFrame( y_pred,columns=labels)

# %%
original_array_pred = df_pred.idxmax(axis=1)

# %%
df_test = pd.DataFrame( y_test,columns=labels)
original_array_test = df_test.idxmax(axis=1)
original_array_test
# Out:
# 0               Office|Computing
# 1               Office|Computing
# 2               Office|Computing
# 3               Office|Computing
# 4               Office|Computing
#                   ...
# 79411    Living_room|Watching_TV
# 79412         Office|Watching_TV
# 79413            Bedroom|Reading
# 79414           Office|Computing
# 79415            Kitchen|Cooking
# Length: 79416, dtype: object

# %%
cm = confusion_matrix(original_array_test,original_array_pred)

# %%
df_cm = pd.DataFrame( cm,columns=labels, index=labels)

# %%
df_cm
# Out:
#                             Bathroom|Cleaning  Bathroom|Showering  \
# Bathroom|Cleaning                           0                   0
# Bathroom|Showering                          0                2521
# Bathroom|Using_the_sink                     0                 278
# Bathroom|Using_the_toilet                   0                   0
# Bedroom|Cleaning                            0                   0
# Bedroom|Dressing                            0                   0
# Bedroom|Napping                             0                   0
# Bedroom|Reading                             0                   0
# Entrance|Entering                           0                   0
# Entrance|Leaving                            0                   0
# Kitchen|Cleaning                            0                   0
# Kitchen|Cooking                             0                   0
# Kitchen|Preparing                           0                   0
# Kitchen|Washing_the_dishes                  0                   0
# Living_room|Cleaning                        0                   0
# Living_room|Computing                       0                   0
# Living_room|Eating                          0                   0
# Living_room|Watching_TV                     0                   0
# Office|Cleaning                             0                   0
# Office|Computing                            0                   0
# Office|Watching_TV                          0                   0
# Staircase|Going_down                        0                   0
# Staircase|Going_up                          0                   0
# Toilet|Using_the_toilet                     0                   0
#
#                             Bathroom|Using_the_sink  \
# Bathroom|Cleaning                                70
# Bathroom|Showering                              154
# Bathroom|Using_the_sink                         602
# Bathroom|Using_the_toilet                       154
# Bedroom|Cleaning                                  0
# Bedroom|Dressing                                  0
# Bedroom|Napping                                   0
# Bedroom|Reading                                   0
# Entrance|Entering                                 0
# Entrance|Leaving                                  0
# Kitchen|Cleaning                                  0
# Kitchen|Cooking                                   0
# Kitchen|Preparing                                 0
# Kitchen|Washing_the_dishes                        0
# Living_room|Cleaning                              0
# Living_room|Computing                             0
# Living_room|Eating                                0
# Living_room|Watching_TV                           0
# Office|Cleaning                                   0
# Office|Computing                                  0
# Office|Watching_TV                                0
# Staircase|Going_down                              0
# Staircase|Going_up                                1
# Toilet|Using_the_toilet                           0
#
#                             Bathroom|Using_the_toilet  Bedroom|Cleaning  \
# Bathroom|Cleaning                                   6                 0
# Bathroom|Showering                                  0                 0
# Bathroom|Using_the_sink                             2                 0
# Bathroom|Using_the_toilet                         126                 0
# Bedroom|Cleaning                                    0                 0
# Bedroom|Dressing                                    0                 0
# Bedroom|Napping                                     0                 0
# Bedroom|Reading                                     0                 0
# Entrance|Entering                                   0                 0
# Entrance|Leaving                                    0                 0
# Kitchen|Cleaning                                    0                 0
# Kitchen|Cooking                                     0                 0
# Kitchen|Preparing                                   0                 0
# Kitchen|Washing_the_dishes                          0                 0
# Living_room|Cleaning                                0                 0
# Living_room|Computing                               0                 0
# Living_room|Eating                                  0                 0
# Living_room|Watching_TV                             0                 0
# Office|Cleaning                                     0                 0
# Office|Computing                                    0                 0
# Office|Watching_TV                                  0                 0
# Staircase|Going_down                                0                 0
# Staircase|Going_up                                  0                 0
# Toilet|Using_the_toilet                             0                 0
#
#                             Bedroom|Dressing  Bedroom|Napping  \
# Bathroom|Cleaning                          0                3
# Bathroom|Showering                         0                0
# Bathroom|Using_the_sink                    0                4
# Bathroom|Using_the_toilet                  0                3
# Bedroom|Cleaning                           4                1
# Bedroom|Dressing                         100               37
# Bedroom|Napping                            3             2960
# Bedroom|Reading                            0                0
# Entrance|Entering                          0                2
# Entrance|Leaving                           0                0
# Kitchen|Cleaning                           0                0
# Kitchen|Cooking                            0                0
# Kitchen|Preparing                          0                0
# Kitchen|Washing_the_dishes                 0                0
# Living_room|Cleaning                       0                0
# Living_room|Computing                      0                0
# Living_room|Eating                         0                0
# Living_room|Watching_TV                    0                0
# Office|Cleaning                            0                0
# Office|Computing                           0               10
# Office|Watching_TV                         0                0
# Staircase|Going_down                       0                5
# Staircase|Going_up                         0               14
# Toilet|Using_the_toilet                    0               18
#
#                             Bedroom|Reading  Entrance|Entering  \
# Bathroom|Cleaning                        12                  0
# Bathroom|Showering                        0                  2
# Bathroom|Using_the_sink                   0                  3
# Bathroom|Using_the_toilet                 0                  0
# Bedroom|Cleaning                         39                  0
# Bedroom|Dressing                        186                  0
# Bedroom|Napping                           3                  0
# Bedroom|Reading                        3182                  0
# Entrance|Entering                         0                267
# Entrance|Leaving                          0                 73
# Kitchen|Cleaning                          0                  0
# Kitchen|Cooking                           0                  0
# Kitchen|Preparing                         0                  0
# Kitchen|Washing_the_dishes                0                  0
# Living_room|Cleaning                      0                  0
# Living_room|Computing                     0                  0
# Living_room|Eating                        0                  0
# Living_room|Watching_TV                   0                  8
# Office|Cleaning                           0                  0
# Office|Computing                          0                  0
# Office|Watching_TV                        0                  0
# Staircase|Going_down                      0                 44
# Staircase|Going_up                        0                 18
# Toilet|Using_the_toilet                   0                 11
#
#                             Entrance|Leaving  ...  Living_room|Cleaning  \
# Bathroom|Cleaning                          0  ...                     0
# Bathroom|Showering                         0  ...                     0
# Bathroom|Using_the_sink                    0  ...                     0
# Bathroom|Using_the_toilet                  0  ...                     0
# Bedroom|Cleaning                           0  ...                     0
# Bedroom|Dressing                           0  ...                     0
# Bedroom|Napping                            0  ...                     0
# Bedroom|Reading                            0  ...                     0
# Entrance|Entering                         36  ...                     1
# Entrance|Leaving                         128  ...                     0
# Kitchen|Cleaning                           0  ...                     6
# Kitchen|Cooking                            0  ...                     0
# Kitchen|Preparing                          0  ...                     7
# Kitchen|Washing_the_dishes                 0  ...                    12
# Living_room|Cleaning                       0  ...                    66
# Living_room|Computing                      0  ...                    31
# Living_room|Eating                         0  ...                    36
# Living_room|Watching_TV                    0  ...                     0
# Office|Cleaning                            0  ...                     0
# Office|Computing                           0  ...                     0
# Office|Watching_TV                         0  ...                     0
# Staircase|Going_down                       0  ...                     2
# Staircase|Going_up                         0  ...                     7
# Toilet|Using_the_toilet                    0  ...                     6
#
#                             Living_room|Computing  Living_room|Eating  \
# Bathroom|Cleaning                               0                   0
# Bathroom|Showering                              0                   0
# Bathroom|Using_the_sink                         3                   3
# Bathroom|Using_the_toilet                       0                   1
# Bedroom|Cleaning                                0                   4
# Bedroom|Dressing                                5                   3
# Bedroom|Napping                                 0                   3
# Bedroom|Reading                                 0                   0
# Entrance|Entering                               0                   3
# Entrance|Leaving                                1                   2
# Kitchen|Cleaning                                0                  22
# Kitchen|Cooking                                 0                   2
# Kitchen|Preparing                               6                   7
# Kitchen|Washing_the_dishes                      6                  14
# Living_room|Cleaning                           52                  45
# Living_room|Computing                        3324                  42
# Living_room|Eating                            180                1600
# Living_room|Watching_TV                         0                   0
# Office|Cleaning                                 0                   0
# Office|Computing                                5                   4
# Office|Watching_TV                              0                   0
# Staircase|Going_down                            0                  18
# Staircase|Going_up                              6                  39
# Toilet|Using_the_toilet                         2                   3
#
#                             Living_room|Watching_TV  Office|Cleaning  \
# Bathroom|Cleaning                                 0                0
# Bathroom|Showering                                4                0
# Bathroom|Using_the_sink                           0                0
# Bathroom|Using_the_toilet                         0                0
# Bedroom|Cleaning                                  0                0
# Bedroom|Dressing                                  0                0
# Bedroom|Napping                                   0                0
# Bedroom|Reading                                   0                0
# Entrance|Entering                                 1                0
# Entrance|Leaving                                  0                0
# Kitchen|Cleaning                                  2                0
# Kitchen|Cooking                                   0                0
# Kitchen|Preparing                                 0                0
# Kitchen|Washing_the_dishes                        0                0
# Living_room|Cleaning                              0                0
# Living_room|Computing                             0                0
# Living_room|Eating                                0                0
# Living_room|Watching_TV                        4024                0
# Office|Cleaning                                   0                1
# Office|Computing                                  3                0
# Office|Watching_TV                                0                0
# Staircase|Going_down                              1                0
# Staircase|Going_up                               17                0
# Toilet|Using_the_toilet                           8                0
#
#                             Office|Computing  Office|Watching_TV  \
# Bathroom|Cleaning                          0                   0
# Bathroom|Showering                         0                   0
# Bathroom|Using_the_sink                    0                   0
# Bathroom|Using_the_toilet                  2                   0
# Bedroom|Cleaning                           0                   0
# Bedroom|Dressing                           0                   0
# Bedroom|Napping                            0                   0
# Bedroom|Reading                            0                   0
# Entrance|Entering                          0                   0
# Entrance|Leaving                           0                   1
# Kitchen|Cleaning                           0                   0
# Kitchen|Cooking                            0                   0
# Kitchen|Preparing                          0                   0
# Kitchen|Washing_the_dishes                 0                   0
# Living_room|Cleaning                       0                   0
# Living_room|Computing                      0                   0
# Living_room|Eating                         0                   0
# Living_room|Watching_TV                    0                   0
# Office|Cleaning                           71                   3
# Office|Computing                       53223                   1
# Office|Watching_TV                        16                1862
# Staircase|Going_down                       1                   1
# Staircase|Going_up                         0                   0
# Toilet|Using_the_toilet                    0                   0
#
#                             Staircase|Going_down  Staircase|Going_up  \
# Bathroom|Cleaning                              0                   0
# Bathroom|Showering                             1                   2
# Bathroom|Using_the_sink                        0                   0
# Bathroom|Using_the_toilet                      0                   0
# Bedroom|Cleaning                               0                   0
# Bedroom|Dressing                               0                   0
# Bedroom|Napping                                0                   0
# Bedroom|Reading                                0                   0
# Entrance|Entering                              1                   3
# Entrance|Leaving                               1                   1
# Kitchen|Cleaning                               1                   7
# Kitchen|Cooking                                0                   0
# Kitchen|Preparing                              0                   1
# Kitchen|Washing_the_dishes                     0                   0
# Living_room|Cleaning                           1                   5
# Living_room|Computing                          0                   0
# Living_room|Eating                             0                   0
# Living_room|Watching_TV                        1                   2
# Office|Cleaning                                0                   0
# Office|Computing                               0                   5
# Office|Watching_TV                             0                   0
# Staircase|Going_down                          50                  37
# Staircase|Going_up                            14                  85
# Toilet|Using_the_toilet                        5                   0
#
#                             Toilet|Using_the_toilet
# Bathroom|Cleaning                                 0
# Bathroom|Showering                                0
# Bathroom|Using_the_sink                           0
# Bathroom|Using_the_toilet                         0
# Bedroom|Cleaning                                  0
# Bedroom|Dressing                                  0
# Bedroom|Napping                                   0
# Bedroom|Reading                                   0
# Entrance|Entering                                 0
# Entrance|Leaving                                  0
# Kitchen|Cleaning                                  0
# Kitchen|Cooking                                   0
# Kitchen|Preparing                                 0
# Kitchen|Washing_the_dishes                        0
# Living_room|Cleaning                              0
# Living_room|Computing                             0
# Living_room|Eating                                0
# Living_room|Watching_TV                           0
# Office|Cleaning                                   0
# Office|Computing                                  7
# Office|Watching_TV                                0
# Staircase|Going_down                              1
# Staircase|Going_up                                2
# Toilet|Using_the_toilet                          80
#
# [24 rows x 24 columns]

# %%
df_cm.to_csv("confusion_matrix_MLP_v2_24_classes.csv",index=True)

# %%
# y_true and y_pred are your true and predicted labels, respectively
report = classification_report(y_test, y_pred, target_names=labels, output_dict=True)

# Calculate the weighted average of precision, recall, and F1 score
precision = report['weighted avg']['precision']
recall = report['weighted avg']['recall']
f1_score = report['weighted avg']['f1-score']
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
weights = np.sum(y_test, axis=0)
precision_weighted = np.sum(precision * weights) / np.sum(weights)
recall_weighted = np.sum(recall * weights) / np.sum(weights)
f1_score_weighted = np.sum(f1_score * weights) / np.sum(weights)

print("Precision:", precision_weighted)
print("Recall:", recall_weighted)
print("F1 score:", f1_score_weighted)
# Out:
# Precision: 0.9679619867845136
# Recall: 0.970346025989725
# F1 score: 0.9664215982527211

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.970346025989725
